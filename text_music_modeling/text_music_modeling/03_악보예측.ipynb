# %% [markdown]
# # 학습목표
# - 시계열을 학습 데이터로 변환
# - LSTM으로 악보 예측

# %%
# 코드 기준 번호 정의 (인코딩)
code2idx = {'c4':0, 'd4':1, 'e4':2, 'f4':3, 'g4':4, 'a4':5, 'b4':6,
            'c8':7, 'd8':8, 'e8':9, 'f8':10, 'g8':11, 'a8':12, 'b8':13}

# 번호 기준 코드 정의 (디코딩)
idx2code = {0:'c4', 1:'d4', 2:'e4', 3:'f4', 4:'g4', 5:'a4', 6:'b4',
            7:'c8', 8:'d8', 9:'e8', 10:'f8', 11:'g8', 12:'a8', 13:'b8'}

# 시퀀스 데이터 정의
seq = ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8',
       'g8', 'g8', 'g4', 'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4',
       'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4', 'd8', 'd8', 'd8',
       'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8',
       'g4', 'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8',
       'g8', 'e8', 'e8', 'e4']

# %%
# 소리변환 함수
# o : 옥타브, s : 음표
def freq(o, s):
    if s[0] == 'c':     return 524*2**o
    elif s[0] == 'd':   return 587*2**o
    elif s[0] == 'e':   return 659*2**o
    elif s[0] == 'f':   return 698*2**o
    elif s[0] == 'g':   return 784*2**o
    elif s[0] == 'a':   return 880*2**o
    elif s[0] == 'b':   return 988*2**o

# %%
# 플레이어
from IPython.display import Audio, display
import numpy as np
import time

def single_tone(frequecy, s, sampling_rate=22050, duration=0.1):
    # frequency: 주파수
    # s : 음표 (4분음표, 8분음표)
    # sampling_rate: 초당 샘플링 데이터 수
    # duration: 지속 시간. 단위 초. 디폴트 1초
    t = np.linspace(0, duration, int(sampling_rate))
    y = np.sin(2 * np.pi * frequecy * t)
    time.sleep(s)
    return y

def play_sound(seq) :
  result = []

  for i in range(len(seq)) :
    # 딜레이를 조절하여 박자를 맞춤
    if seq[i][1] == "4" :
        result.append(single_tone(freq(2, seq[i]), 0.5))
    elif seq[i][1] == "8" :
        result.append(single_tone(freq(2, seq[i]), 0.25))

    octave = np.hstack(result)

  display(Audio(octave, rate=44100))

# %%
play_sound(seq)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# - 시계열을 학습 데이터(특성, 라벨)로 변환하는 함수

# %%
# 노래 데이터를 window_size만큼의 크기로 각각 분리
def split_seq(seq,window_size):
    data_set=[]

    for i in range(len(seq)-window_size):

        # window_size+1만큼 잘라서 저장
        subset = seq[i:(i+window_size+1)]

        # 음표를 인코딩해서 저장
        data_set.append([code2idx[item] for item in subset])

    return data_set

# %%
import numpy as np

data_set2 = np.array(split_seq(seq, 4))
print(data_set2.shape)
print(data_set2)

# %%
X=data_set2[:,:4]
y=data_set2[:,-1]
print(x.shape, y.shape)
# Out:
# (50, 4) (50,)

# %% [markdown]
# - 라벨을 원핫인코딩

# %%
from tensorflow.keras.utils import to_categorical

# 정규화 (0-1사이 값으로변환)
X=X/13.0
y=to_categorical(y)
print(y.shape)
# Out:
# (50, 12)

# %% [markdown]
# - 특성 데이터의 특성(시간) 차원을 추가
#   - 온도 데이터 시계열, 습도 데이터 시계열, 기압 데이터 시계열 (특성차원) -> 날씨 예측
# - f8 -> 1개의 특성
# - f와 8을 분리하면 -> 2개의 특성

# %%
X_ex=np.reshape(X,(50,4,1))
print(X_ex.shape)
# Out:
# (50, 4, 1)

# %% [markdown]
# - 신경망 설계

# %%
# prompt: 신경망 설계

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
model1 = Sequential()

# (1,4,1) : 배치 크기, 특성 데이터의 시간 수, 특성 수(음계+박자)
# stateful=True : 1개씩 처리해서 다음 단계로 결과를 넘겨준다

model1.add(LSTM(units=128,batch_input_shape=(1,4,1),stateful=True))
model1.add(Dense(12, activation='softmax'))
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (1, 128)                  66560
#
#  dense_1 (Dense)             (1, 12)                   1548
#
# =================================================================
# Total params: 68108 (266.05 KB)
# Trainable params: 68108 (266.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# prompt: 컴파일

model1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
for epoch_idx in range(500):

  # shuffle=False : 악보는 섞으면 안되므오 False로 설정
  # batch_size=1 : 악보라서 하나씩
  model1.fit(X_ex,y,epochs=1, batch_size=1,verbose=2,shuffle=False)

  # stateful 을 설정하고 리셋하지 않으면 이전과 값들이 더해서 쌓이므로 리셋 필요
  model1.reset_states()
# Out:
# 50/50 - 2s - loss: 2.3987 - accuracy: 0.1600 - 2s/epoch - 49ms/step
# 50/50 - 0s - loss: 2.0208 - accuracy: 0.3400 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9632 - accuracy: 0.3400 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9462 - accuracy: 0.3400 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9366 - accuracy: 0.3400 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9297 - accuracy: 0.3400 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9243 - accuracy: 0.3400 - 150ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9197 - accuracy: 0.3400 - 203ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.9157 - accuracy: 0.3400 - 205ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.9120 - accuracy: 0.3400 - 394ms/epoch - 8ms/step
# 50/50 - 0s - loss: 1.9084 - accuracy: 0.3600 - 222ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.9046 - accuracy: 0.3600 - 203ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.9004 - accuracy: 0.3600 - 206ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.8955 - accuracy: 0.3600 - 285ms/epoch - 6ms/step
# 50/50 - 0s - loss: 1.8896 - accuracy: 0.3600 - 218ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.8870 - accuracy: 0.3800 - 194ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.8725 - accuracy: 0.3600 - 194ms/epoch - 4ms/step
# 50/50 - 0s - loss: 2.2588 - accuracy: 0.3000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8943 - accuracy: 0.3400 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8819 - accuracy: 0.3400 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8720 - accuracy: 0.3600 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8632 - accuracy: 0.3600 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8555 - accuracy: 0.3600 - 161ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8387 - accuracy: 0.3800 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8372 - accuracy: 0.3800 - 148ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8154 - accuracy: 0.3800 - 264ms/epoch - 5ms/step
# 50/50 - 0s - loss: 1.8853 - accuracy: 0.3600 - 217ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.8521 - accuracy: 0.3600 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8025 - accuracy: 0.4200 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7963 - accuracy: 0.3400 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7583 - accuracy: 0.3400 - 148ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7929 - accuracy: 0.3400 - 148ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7733 - accuracy: 0.4000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7097 - accuracy: 0.4200 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9091 - accuracy: 0.4000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8459 - accuracy: 0.3800 - 148ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7659 - accuracy: 0.3800 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7354 - accuracy: 0.4200 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8177 - accuracy: 0.3200 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7991 - accuracy: 0.3600 - 164ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7060 - accuracy: 0.4400 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7044 - accuracy: 0.4200 - 192ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.7265 - accuracy: 0.4000 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7048 - accuracy: 0.3800 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.8084 - accuracy: 0.3400 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.7932 - accuracy: 0.3400 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.
ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0491 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0434 - accuracy: 1.0000 - 164ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0385 - accuracy: 1.0000 - 304ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0345 - accuracy: 1.0000 - 204ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0310 - accuracy: 1.0000 - 268ms/epoch - 5ms/step
# 50/50 - 0s - loss: 0.0281 - accuracy: 1.0000 - 295ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0255 - accuracy: 1.0000 - 272ms/epoch - 5ms/step
# 50/50 - 0s - loss: 0.0233 - accuracy: 1.0000 - 238ms/epoch - 5ms/step
# 50/50 - 0s - loss: 0.0214 - accuracy: 1.0000 - 296ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0196 - accuracy: 1.0000 - 320ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0181 - accuracy: 1.0000 - 220ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0167 - accuracy: 1.0000 - 316ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0155 - accuracy: 1.0000 - 296ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0143 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0133 - accuracy: 1.0000 - 165ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0124 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0115 - accuracy: 1.0000 - 226ms/epoch - 5ms/step
# 50/50 - 0s - loss: 0.0107 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0100 - accuracy: 1.0000 - 161ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0093 - accuracy: 1.0000 - 176ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0087 - accuracy: 1.0000 - 175ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0082 - accuracy: 1.0000 - 153ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0076 - accuracy: 1.0000 - 223ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0072 - accuracy: 1.0000 - 317ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0067 - accuracy: 1.0000 - 277ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0063 - accuracy: 1.0000 - 204ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0060 - accuracy: 1.0000 - 194ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0056 - accuracy: 1.0000 - 225ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0053 - accuracy: 1.0000 - 328ms/epoch - 7ms/step
# 50/50 - 0s - loss: 0.0050 - accuracy: 1.0000 - 225ms/epoch - 5ms/step
# 50/50 - 0s - loss: 0.0048 - accuracy: 1.0000 - 317ms/epoch - 6ms/step
# 50/50 - 0s - loss: 0.0045 - accuracy: 1.0000 - 195ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.0043 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0041 - accuracy: 1.0000 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0039 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0037 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0035 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0034 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0032 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0031 - accuracy: 1.0000 - 155ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0029 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0028 - accuracy: 1.0000 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0027 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0026 - accuracy: 1.0000 - 152ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0025 - accuracy: 1.0000 - 155ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0024 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0023 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0022 - accuracy: 1.0000 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0021 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0020 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0020 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0019 - accuracy: 1.0000 - 153ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0018 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0017 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0017 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0016 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0015 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0015 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0014 - accuracy: 1.0000 - 162ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0014 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0013 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0013 - accuracy: 1.0000 - 148ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0012 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0012 - accuracy: 1.0000 - 151ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0011 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0011 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0011 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.0010 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 9.9564e-04 - accuracy: 1.0000 - 237ms/epoch - 5ms/step
# 50/50 - 0s - loss: 9.6125e-04 - accuracy: 1.0000 - 224ms/epoch - 4ms/step
# 50/50 - 0s - loss: 9.2824e-04 - accuracy: 1.0000 - 189ms/epoch - 4ms/step
# 50/50 - 0s - loss: 8.9653e-04 - accuracy: 1.0000 - 204ms/epoch - 4ms/step
# 50/50 - 0s - loss: 8.6606e-04 - accuracy: 1.0000 - 189ms/epoch - 4ms/step
# 50/50 - 0s - loss: 8.3678e-04 - accuracy: 1.0000 - 202ms/epoch - 4ms/step
# 50/50 - 0s - loss: 8.0857e-04 - accuracy: 1.0000 - 227ms/epoch - 5ms/step
# 50/50 - 0s - loss: 7.8146e-04 - accuracy: 1.0000 - 197ms/epoch - 4ms/step
# 50/50 - 0s - loss: 7.5535e-04 - accuracy: 1.0000 - 193ms/epoch - 4ms/step
# 50/50 - 0s - loss: 7.3022e-04 - accuracy: 1.0000 - 190ms/epoch - 4ms/step
# 50/50 - 0s - loss: 7.0606e-04 - accuracy: 1.0000 - 240ms/epoch - 5ms/step
# 50/50 - 0s - loss: 6.8279e-04 - accuracy: 1.0000 - 153ms/epoch - 3ms/step
# 50/50 - 0s - loss: 6.6042e-04 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 6.3889e-04 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 6.1817e-04 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 5.9823e-04 - accuracy: 1.0000 - 157ms/epoch - 3ms/step
# 50/50 - 0s - loss: 5.7905e-04 - accuracy: 1.0000 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 5.6059e-04 - accuracy: 1.0000 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 5.4285e-04 - accuracy: 1.0000 - 154ms/epoch - 3ms/step
# 50/50 - 0s - loss: 5.2578e-04 - accuracy: 1.0000 - 148ms/epoch - 3ms/step
# 50/50 - 0s - loss: 5.0934e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4.9352e-04 - accuracy: 1.0000 - 155ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4.7827e-04 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4.6359e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4.4943e-04 - accuracy: 1.0000 - 161ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4.3579e-04 - accuracy: 1.0000 - 156ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4.2260e-04 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4.0988e-04 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.9762e-04 - accuracy: 1.0000 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.8577e-04 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.7433e-04 - accuracy: 1.0000 - 157ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.6326e-04 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.5257e-04 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.4224e-04 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.3225e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.2261e-04 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.1327e-04 - accuracy: 1.0000 - 153ms/epoch - 3ms/step
# 50/50 - 0s - loss: 3.0424e-04 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.9552e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.8710e-04 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.7895e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.7106e-04 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.6343e-04 - accuracy: 1.0000 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.5602e-04 - accuracy: 1.0000 - 152ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.4883e-04 - accuracy: 1.0000 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.4186e-04 - accuracy: 1.0000 - 165ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.3510e-04 - accuracy: 1.0000 - 208ms/epoch - 4ms/step
# 50/50 - 0s - loss: 2.2853e-04 - accuracy: 1.0000 - 227ms/epoch - 5ms/step
# 50/50 - 0s - loss: 2.2214e-04 - accuracy: 1.0000 - 212ms/epoch - 4ms/step
# 50/50 - 0s - loss: 2.1592e-04 - accuracy: 1.0000 - 192ms/epoch - 4ms/step
# 50/50 - 0s - loss: 2.0990e-04 - accuracy: 1.0000 - 201ms/epoch - 4ms/step
# 50/50 - 0s - loss: 2.0398e-04 - accuracy: 1.0000 - 229ms/epoch - 5ms/step
# 50/50 - 0s - loss: 1.9827e-04 - accuracy: 1.0000 - 280ms/epoch - 6ms/step
# 50/50 - 0s - loss: 1.9270e-04 - accuracy: 1.0000 - 210ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.8727e-04 - accuracy: 1.0000 - 218ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.8198e-04 - accuracy: 1.0000 - 201ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.7686e-04 - accuracy: 1.0000 - 208ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.7186e-04 - accuracy: 1.0000 - 214ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.6702e-04 - accuracy: 1.0000 - 201ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.6228e-04 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.5766e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.5318e-04 - accuracy: 1.0000 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.4883e-04 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.4458e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.4046e-04 - accuracy: 1.0000 - 151ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.3648e-04 - accuracy: 1.0000 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.3261e-04 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.2884e-04 - accuracy: 1.0000 - 152ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.2519e-04 - accuracy: 1.0000 - 150ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.2162e-04 - accuracy: 1.0000 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.1820e-04 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.1487e-04 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.1162e-04 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.0849e-04 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.0544e-04 - accuracy: 1.0000 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.0249e-04 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 9.9634e-05 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 9.6922e-05 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 9.4280e-05 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 9.1784e-05 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 8.9412e-05 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 8.7174e-05 - accuracy: 1.0000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 8.5019e-05 - accuracy: 1.0000 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 8.2971e-05 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 8.0966e-05 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 7.8993e-05 - accuracy: 1.0000 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 7.7004e-05 - accuracy: 1.0000 - 182ms/epoch - 4ms/step
# 50/50 - 0s - loss: 7.4988e-05 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 7.2926e-05 - accuracy: 1.0000 - 262ms/epoch - 5ms/step
# 50/50 - 0s - loss: 7.0859e-05 - accuracy: 1.0000 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 6.8780e-05 - accuracy: 1.0000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 6.6766e-05 - accuracy: 1.0000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 6.4813e-05 - accuracy: 1.0000 - 206ms/epoch - 4ms/step
# 50/50 - 0s - loss: 6.2944e-05 - accuracy: 1.0000 - 243ms/epoch - 5ms/step
# 50/50 - 0s - loss: 6.1137e-05 - accuracy: 1.0000 - 186ms/epoch - 4ms/step
# 50/50 - 0s - loss: 5.9432e-05 - accuracy: 1.0000 - 195ms/epoch - 4ms/step
# 50/50 - 0s - loss: 5.7783e-05 - accuracy: 1.0000 - 190ms/epoch - 4ms/step
# 50/50 - 0s - loss: 5.6186e-05 - accuracy: 1.0000 - 203ms/epoch - 4ms/step
# 50/50 - 0s - loss: 5.4684e-05 - accuracy: 1.0000 - 224ms/epoch - 4ms/step
# 50/50 - 0s - loss: 5.3206e-05 - accuracy: 1.0000 - 196ms/epoch - 4ms/step
# 50/50 - 0s - loss: 5.1785e-05 - accuracy: 1.0000 - 240ms/epoch - 5ms/step
# 50/50 - 0s - loss: 5.0395e-05 - accuracy: 1.0000 - 196ms/epoch - 4ms/step
# 50/50 - 0s - loss: 4.9067e-05 - accuracy: 1.0000 - 188ms/epoch - 4ms/step
# 50/50 - 0s - loss: 4.7775e-05 - accuracy: 1.0000 - 207ms/epoch - 4ms/step
# 50/50 - 0s - loss: 4.6502e-05 - accuracy: 1.0000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 4
ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.0880 - accuracy: 0.6200 - 194ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.8318 - accuracy: 0.7200 - 192ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.2287 - accuracy: 0.5600 - 200ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.9846 - accuracy: 0.6200 - 199ms/epoch - 4ms/step
# 50/50 - 0s - loss: 0.8885 - accuracy: 0.6800 - 203ms/epoch - 4ms/step
# 50/50 - 0s - loss: 1.6100 - accuracy: 0.3600 - 227ms/epoch - 5ms/step
# 50/50 - 0s - loss: 1.1930 - accuracy: 0.5000 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.7336 - accuracy: 0.7000 - 149ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.5820 - accuracy: 0.7800 - 138ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.4732 - accuracy: 0.8200 - 148ms/epoch - 3ms/step
# 50/50 - 0s - loss: 2.4061 - accuracy: 0.4200 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.3714 - accuracy: 0.5200 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.1511 - accuracy: 0.5600 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.8412 - accuracy: 0.6600 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.5697 - accuracy: 0.8800 - 153ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.3659 - accuracy: 0.9600 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.2018 - accuracy: 0.9800 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.3643 - accuracy: 0.8600 - 151ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.9062 - accuracy: 0.6000 - 140ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.0720 - accuracy: 0.5000 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.8803 - accuracy: 0.6400 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.9420 - accuracy: 0.6400 - 145ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.4431 - accuracy: 0.8600 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.3019 - accuracy: 0.6600 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.9698 - accuracy: 0.6600 - 143ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.7075 - accuracy: 0.6800 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 1.0544 - accuracy: 0.6200 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.5141 - accuracy: 0.8000 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.5034 - accuracy: 0.8200 - 154ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.8737 - accuracy: 0.7000 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.8783 - accuracy: 0.6800 - 142ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.9704 - accuracy: 0.5600 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.8293 - accuracy: 0.7200 - 146ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.5135 - accuracy: 0.8200 - 156ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.5074 - accuracy: 0.8600 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.4200 - accuracy: 0.9000 - 144ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.2487 - accuracy: 0.9600 - 155ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.3736 - accuracy: 0.8800 - 141ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.8462 - accuracy: 0.6800 - 147ms/epoch - 3ms/step
# 50/50 - 0s - loss: 0.3495 - accuracy: 0.9000 - 143ms/epoch - 3ms/step

# %% [markdown]
# - 악보예측

# %%
co = 50 # 예측할 갯수

# 초기악보
seq_out = ['d8','e8','f4','f8']

# 초기 악보 4개로 전체 악보 예측
pred_out = model1.predict(X_ex, batch_size=1)
# Out:
# 50/50 [==============================] - 0s 2ms/step

# %%
# 50개 예측 악보 출력
for  i in range(co) :

  # 가장 큰 확률 값을 가진 악보의 인덱스를 반환
  pred_i = np.argmax(pred_out[i])

  # 해당 인덱스의 악보를 기존 4개의 악보에 이어서 저장
  seq_out.append(idx2code[pred_i])

print("원래악보",seq)
print("예측악보",seq_out)
# Out:
# 원래악보 ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'g8', 'g4', 'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4', 'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4', 'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']
# 예측악보 ['d8', 'e8', 'f4', 'f8', 'd8', 'd8', 'd8', 'd8', 'g8', 'd8', 'e8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'e8', 'f4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e8', 'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'd8', 'e8', 'e8', 'e8', 'e8', 'e8', 'f4', 'e8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']

# %%
play_sound(seq)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
